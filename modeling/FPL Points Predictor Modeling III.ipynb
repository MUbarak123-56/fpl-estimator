# %% [markdown]
# # FPL Predictor Modeling III

# %% [markdown]
# ### Package Installments

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style = "ticks")
# %matplotlib inline
from scipy.interpolate import make_interp_spline
import math
import pickle

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import validation_curve
from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline

# %% [markdown]
# ### Useful functions

# %%
## This function is used to select the best degree for polynomial regression
def best_degree(model, df_x,df_y):
    degree = np.arange(10)
    train_score, val_score = validation_curve(estimator = model, X = df_x, y = df_y,param_name = 'polynomialfeatures__degree', 
                                              param_range = degree, cv = 5)
    degree = pd.Series(degree)
    train = pd.Series(np.median(train_score,1))
    val = pd.Series(np.median(val_score,1))
    record = pd.DataFrame({'degree': degree, 'train_score': train, 'val_score': val})
    record_max = record.loc[record[['val_score']].idxmax(), 'degree']
    record_max2 = record_max.reset_index(drop = True)
    return record_max2[0]

# %%
## This function is used to see how the training curve and validation curve vary for different degrees
def val_curve(model, df_x, df_y):
    degree = np.arange(1,6)
    train_score, val_score = validation_curve(estimator = model,X = df_x, y = df_y, param_name = 'polynomialfeatures__degree',
                                              param_range = degree, cv = 5)
    best = best_degree(model,df_x,df_y)
    deg = np.linspace(1,5,200)
    smooth_train = make_interp_spline(degree, np.median(train_score,1))
    smooth_val = make_interp_spline(degree, np.median(val_score, 1))

    ##plt.plot(degree, np.median(train_score,1), color = 'blue', label = 'training curve')
    ##plt.plot(degree, np.median(val_score,1), color = 'red', label = 'validation curve')
    plt.plot(deg, smooth_train(deg), color = 'blue', label = 'training curve')
    plt.plot(deg, smooth_val(deg), color = 'red', label = 'validation curve')
    plt.scatter(best, np.max(np.median(val_score,1)), marker = 'x', color = 'black', label = 'max')
    plt.legend(loc = 'best')
    plt.xlabel('Degree')
    plt.ylabel('Accuracy score')
    plt.ylim(0,1);

# %%
## This function is used split data into training and testing sets
def split_data(df_new, rand_state = 69):
    df_x = df_new.drop("total_points", axis = 1)
    df_y = df_new['total_points']
    df_xm = df_new[['goals_scored','assists','minutes','clean_sheets','position_index']]
    df_xtrain, df_xtest, df_ytrain, df_ytest = train_test_split(df_x, df_y, random_state = rand_state, train_size = 0.75)
    df_xtrain_new = df_xtrain[['position_index','goals_scored', 'assists', 'ict_index', 'goals_conceded', 'minutes', 
                               'own_goals', 'bps', 'bonus', 'clean_sheets', 'GW']]
    df_xtest_new = df_xtest[['position_index','goals_scored', 'assists', 'ict_index', 'goals_conceded', 'minutes',
                             'own_goals', 'bps', 'bonus', 'clean_sheets', 'GW']]
    return (df_x, df_y, df_xm, df_xtrain, df_xtest, df_ytrain, df_ytest, df_xtrain_new, df_xtest_new)

# %%
## This function is used to generate a new table with the fpl predictions
def new_output(df_x, df_y, df_pred):
    df_xtest = df_x.copy()
    df_xtest["total"] = df_y
    df_xtest['fpl_pred'] = df_pred
    df_xtest2 = df_xtest.reset_index()
    df_xtest2 = df_xtest2.drop("index", axis = 1)
    return df_xtest2

# %% [markdown]
# ### ETL

# %%
## Loading the dataset
fpl_ult = pd.read_csv("~/DSI-SRP1/FPL_ULTIMATE.csv", encoding = "latin1")

# %%
fpl_ult.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'club_name', 'position', 'position_index',
#        'goals_scored', 'assists', 'ict_index', 'goals_conceded', 'minutes',
#        'own_goals', 'total_points', 'bps', 'bonus', 'clean_sheets', 'GW',
#        'season'],
#       dtype='object')

# %%
fpl_ult.shape
# Out:
# (46659, 17)

# %%
fpl_ult.head()
# Out:
#    Unnamed: 0     player_name         club_name            position  \
# 0           1    Aaron Lennon        Everton FC        Right Winger
# 1           2    Aaron Ramsey        Arsenal FC    Central Midfield
# 2           3  Abel Hernández         Hull City      Centre-Forward
# 3           4  Adama Diomande         Hull City      Centre-Forward
# 4           5    Adam Clayton  Middlesbrough FC  Defensive Midfield
#
#    position_index  goals_scored  assists  ict_index  goals_conceded  minutes  \
# 0               4             0        0        0.9               0       15
# 1               3             0        0        3.0               3       60
# 2               5             0        1        5.7               1       90
# 3               5             1        0       10.7               1       90
# 4               3             0        0        1.4               1       90
#
#    own_goals  total_points  bps  bonus  clean_sheets  GW     season
# 0          0             1    6      0             0   1  2016/2017
# 1          0             2    5      0             0   1  2016/2017
# 2          0             5   10      0             0   1  2016/2017
# 3          0             8   29      2             0   1  2016/2017
# 4          0             2    6      0             0   1  2016/2017

# %%
fpl_ult = fpl_ult.drop("Unnamed: 0", axis = 1)

# %%
fpl_ult.columns
# Out:
# Index(['player_name', 'club_name', 'position', 'position_index',
#        'goals_scored', 'assists', 'ict_index', 'goals_conceded', 'minutes',
#        'own_goals', 'total_points', 'bps', 'bonus', 'clean_sheets', 'GW',
#        'season'],
#       dtype='object')

# %%
fpl_ult.shape
# Out:
# (46659, 16)

# %% [markdown]
# ### Train and Testing Split

# %%
fpl_x, fpl_y, fpl_xm, fpl_xtrain, fpl_xtest, fpl_ytrain, fpl_ytest, fpl_xtrain_new, fpl_xtest_new = split_data(fpl_ult)

# %% [markdown]
# ### Feature Selection

# %%
## plotting the correlation coefficient table
plt.figure(figsize = (24,15))
cor = fpl_ult.corr()
sns.heatmap(cor, annot = True, cmap = 'viridis')
plt.show()

# %%
##  Using Recursive Feature Elimination to select variables
#fpl_newx = fpl_ult[['goals_scored','assists','minutes','bonus','bps','goals_conceded', 'clean_sheets','ict_index','position_index','GW']]
#fpl_newy = fpl_ult['total_points']
from sklearn.feature_selection import RFECV
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
model2 = LinearRegression()
model_rfe = RFE(model2,n_features_to_select= 4)
fpl_x_rfe = model_rfe.fit_transform(fpl_xtrain_new, fpl_ytrain)
model2.fit(fpl_x_rfe, fpl_ytrain)
rfe = model_rfe.ranking_
features = ['position_index','goals_scored', 'assists', 'ict_index', 'goals_conceded', 'minutes','own_goals', 
            'bps', 'bonus', 'clean_sheets', 'GW']
ref_df = pd.DataFrame({'features': features, 'rfe_rank': rfe}, index = np.arange(len(features)))
ref_df[ref_df['rfe_rank'] == 1]
# Out:
#          features  rfe_rank
# 0  position_index         1
# 1    goals_scored         1
# 6       own_goals         1
# 9    clean_sheets         1

# %%
## minutes was selected because intuitively speaking the number of minutes a player plays has an influence on his total_points
fpl_newx2 = fpl_xtrain[['goals_scored', 'assists','clean_sheets', 'position_index', 'minutes']]
model_rfe2 = RFE(model2, n_features_to_select = 1)
fpl_x_rfe2 = model_rfe2.fit_transform(fpl_newx2, fpl_ytrain)
model2.fit(fpl_x_rfe2, fpl_ytrain)
rfe2 = model_rfe2.ranking_
features2 = ['goals_scored','assists','clean_sheets','position_index', 'minutes']
rfe_df2 = pd.DataFrame({'features': features2, 'rfe_rank': rfe2}, index = np.arange(5))
rfe_df2 = rfe_df2.sort_values('rfe_rank')
rfe_df3 = rfe_df2.reset_index()
rfe_df3 = rfe_df3.drop('index', axis = 1)
rfe_df3
# Out:
#          features  rfe_rank
# 0    clean_sheets         1
# 1    goals_scored         2
# 2  position_index         3
# 3         assists         4
# 4         minutes         5

# %%
fpl_xtrain_new = fpl_xtrain_new[list(rfe_df3["features"])]
fpl_xtest_new = fpl_xtest_new[list(rfe_df3["features"])]

# %% [markdown]
# ### Modeling

# %%
model = make_pipeline(PolynomialFeatures(), LinearRegression())

# %%
val_curve(model, fpl_xtrain_new, fpl_ytrain)

# %%
## building a new model based on the best degree
model_fpl = make_pipeline(PolynomialFeatures(best_degree(model, fpl_xtrain_new, fpl_ytrain)), LinearRegression())

# %%
score_fpl = cross_val_score(model_fpl, fpl_xtrain_new, fpl_ytrain, cv = 5, scoring = "r2")
print(score_fpl)
print(score_fpl.mean())
# Out:
# [0.9778394  0.99244434 0.9927798  0.99107625 0.9938096 ]
# 0.9895898774099304

# %%
## fitting the model
model_fpl.fit(fpl_xtrain_new, fpl_ytrain)
fpl_pred = model_fpl.predict(fpl_xtest_new)

# %%
fpl_r2 = r2_score(fpl_pred, fpl_ytest)

# %%
fpl_rmse = math.sqrt(mean_squared_error(fpl_pred, fpl_ytest))

# %%
fpl_evs = explained_variance_score(fpl_pred, fpl_ytest)

# %%
## creating a table for the metrics
index = [0,1,2]
measure = ['r-squared score', 'root mean squared error', 'explained variance score']
score = [fpl_r2, fpl_rmse, fpl_evs]
fpl_score_df = pd.DataFrame({'measure': measure, 'score': score}, index = index)
fpl_score_df
# Out:
#                     measure     score
# 0           r-squared score  0.993745
# 1   root mean squared error  6.793562
# 2  explained variance score  0.993745

# %%
fpl_xtrain = fpl_xtrain[['GW','player_name','goals_scored', 'assists','minutes', 'position_index','clean_sheets']]
fpl_xtest = fpl_xtest[['GW','player_name','goals_scored', 'assists','minutes', 'position_index','clean_sheets']]

# %%
fpl_ult2 = new_output(fpl_xtest, fpl_ytest, fpl_pred)

# %%
from sklearn.model_selection import cross_val_predict
fpl_pred2 = cross_val_predict(model_fpl, fpl_xtrain_new, fpl_ytrain, cv = 5)
fpl_ult3 = new_output(fpl_xtrain, fpl_ytrain, fpl_pred2)

# %%
fpl_ult2.head()
# Out:
#    GW    player_name  goals_scored  assists  minutes  position_index  \
# 0  36  Davy Klaassen             0        0      193               4
# 1  25  Florin Andone             2        0      529               5
# 2  89      Petr Cech             0        0     6721               1
# 3  34  Scott Arfield             1        2     1767               3
# 4  37  Uwe Hünemeier             0        0       17               2
#
#    clean_sheets  total    fpl_pred
# 0             0      5    6.843320
# 1             1     28   26.626819
# 2            24    282  285.527036
# 3             5     60   58.881503
# 4             0      1    1.280533

# %%
fpl_u = pd.concat([fpl_ult3, fpl_ult2], axis = 0)
fpl_u.to_csv("~/DSI-SRP1/FPL_NEW.csv")

# %% [markdown]
# ### 2019/20 sample dataset

# %%
## Loading a new data
fpl_test = pd.read_csv("~/DSI-SRP1/2019_20_sample.csv")

# %%
fpl_test.head()
# Out:
#    Unnamed: 0 player_name  goals_scored  assists  minutes  position_index  \
# 0           1     Alisson             0        1     2363               1
# 1           2       Bravo             0        0      347               1
# 2           3      de Gea             0        0     3240               1
# 3           4   Caballero             0        0      360               1
# 4           5        Gunn             0        0      900               1
#
#    clean_sheets  total_points  fpl_to_game
# 0            13           119     4.532374
# 1             1            11     2.853026
# 2            12           134     3.722222
# 3             0             7     1.750000
# 4             5            29     2.900000

# %%
fpl_test = fpl_test.drop("Unnamed: 0", axis = 1)
fpl_test.columns
# Out:
# Index(['player_name', 'goals_scored', 'assists', 'minutes', 'position_index',
#        'clean_sheets', 'total_points', 'fpl_to_game'],
#       dtype='object')

# %%
## testing out the model on a new dataset
fpl_testx = fpl_test[list(rfe_df3["features"])]
fpl_testpred = model_fpl.predict(fpl_testx)

# %%
fpl_t = fpl_test.copy()
fpl_t['total_points_pred'] = fpl_testpred
fpl_t['fpl_to_game_pred'] = (fpl_testpred/fpl_test['minutes'])*90
fpl_t
# Out:
#     player_name  goals_scored  assists  minutes  position_index  clean_sheets  \
# 0       Alisson             0        1     2363               1            13
# 1         Bravo             0        0      347               1             1
# 2        de Gea             0        0     3240               1            12
# 3     Caballero             0        0      360               1             0
# 4          Gunn             0        0      900               1             5
# 5          Pope             0        0     3330               1            15
# 6      van Dijk             4        1     3240               2            15
# 7         Coady             0        0     3240               2            12
# 8          Rico             0        3     2242               2             6
# 9        Cahill             0        1     2167               2             7
# 10        Pogba             1        3     1024               3             5
# 11      Fabinho             2        3     1989               3             8
# 12     Jorginho             4        2     2202               3             5
# 13        Winks             0        0     2131               3             7
# 14     Grealish             7        6     3053               4             6
# 15     Sterling            17        1     2498               4            10
# 16         Pepe             5        6     1908               4             7
# 17        Salah            19        9     2779               4            13
# 18  Richarlison            12        3     2890               5             8
# 19      Firmino             8        7     2875               5            15
# 20      Solanke             2        1     1588               5             3
# 21        Vardy            23        5     2943               5            12
#
#     total_points  fpl_to_game  total_points_pred  fpl_to_game_pred
# 0            119     4.532374         126.138906          4.804275
# 1             11     2.853026          14.966164          3.881714
# 2            134     3.722222         141.676454          3.935457
# 3              7     1.750000           8.766203          2.191551
# 4             29     2.900000          48.075585          4.807559
# 5            169     4.567568         156.036155          4.217193
# 6            168     4.666667         158.172109          4.393670
# 7            116     3.222222         109.014180          3.028172
# 8             77     3.090990          73.657928          2.956830
# 9             70     2.907245          70.732311          2.937659
# 10            47     4.130859          47.548038          4.179027
# 11            75     3.393665          79.492206          3.596932
# 12            87     3.555858          86.590356          3.539115
# 13            50     2.111685          52.291287          2.208454
# 14           135     3.979692         147.474388          4.347427
# 15           179     6.449159         177.557106          6.397174
# 16           103     4.858491         107.265149          5.059677
# 17           227     7.351565         227.661047          7.372974
# 18           156     4.858131         139.819370          4.354236
# 19           143     4.476522         154.213050          4.827539
# 20            63     3.570529          58.084538          3.291945
# 21           209     6.391437         202.643790          6.197058

# %% [markdown]
# ### 2020/21 dataset ~ After 12 games

# %%
df_21 = pd.read_csv("~/DSI-SRP1/Premier_league.csv", encoding = "latin1")

# %%
df_21.head()
# Out:
#    Unnamed: 0         player_name               club_name  recent_GW  minutes  \
# 0           1      Aaron Connolly  Brighton & Hove Albion         12      441
# 1           2     Aaron Cresswell         West Ham United         12     1080
# 2           3      Aaron Ramsdale        Sheffield United         12     1080
# 3           4   Aaron Wan-Bissaka       Manchester United         11      900
# 4           5  Abdoulaye Doucouré              Everton FC         12      998
#
#    position_index  goals_scored  assists  clean_sheets  total_points
# 0               5             1        1             1            23
# 1               2             0        4             4            53
# 2               1             0        0             0            28
# 3               2             1        0             3            35
# 4               3             1        1             2            31

# %%
df_21 = df_21.drop("Unnamed: 0", axis = 1)

# %%
df_21.head()
# Out:
#           player_name               club_name  recent_GW  minutes  \
# 0      Aaron Connolly  Brighton & Hove Albion         12      441
# 1     Aaron Cresswell         West Ham United         12     1080
# 2      Aaron Ramsdale        Sheffield United         12     1080
# 3   Aaron Wan-Bissaka       Manchester United         11      900
# 4  Abdoulaye Doucouré              Everton FC         12      998
#
#    position_index  goals_scored  assists  clean_sheets  total_points
# 0               5             1        1             1            23
# 1               2             0        4             4            53
# 2               1             0        0             0            28
# 3               2             1        0             3            35
# 4               3             1        1             2            31

# %%
plt.figure(figsize = (20,8))
plt.scatter(x = "minutes", y = "total_points", data = df_21, marker = "x", color = "purple")
plt.xlabel("minutes played", fontsize = 16)
plt.ylabel("FPL points", fontsize = 16)
plt.title("FPL points vs minutesplayed after 12 games in 2020/21");

# %%
df_21_x = df_21[['player_name','club_name','goals_scored', 'assists','minutes','clean_sheets', 'position_index', 'total_points']]
df_21_x_train = df_21_x[list(rfe_df3["features"])]

# %%
df_21_pred = model_fpl.predict(df_21_x_train)

# %%
r2_score(df_21_x['total_points'], df_21_pred)
# Out:
# 0.9486255179373191

# %%
df_21_x['Predicted Points'] = df_21_pred
df_21_x['Actual FPPG'] = (df_21_x['total_points']/df_21_x['minutes'])*90
df_21_x['Predicted FPPG'] = (df_21_x['Predicted Points']/df_21_x['minutes'])*90

# %%
df_21_x.head(30)
# Out:
#                        player_name                club_name  goals_scored  \
# 0                   Aaron Connolly   Brighton & Hove Albion             1
# 1                  Aaron Cresswell          West Ham United             0
# 2                   Aaron Ramsdale         Sheffield United             0
# 3                Aaron Wan-Bissaka        Manchester United             1
# 4               Abdoulaye Doucouré               Everton FC             1
# 5                 Aboubakar Kamara                Fulham FC             0
# 6                     Adam Lallana   Brighton & Hove Albion             0
# 7                     Adam Webster   Brighton & Hove Albion             0
# 8                     Adama Traoré  Wolverhampton Wanderers             0
# 9                  Ademola Lookman                Fulham FC             2
# 10  Adrián San Miguel del Castillo             Liverpool FC             0
# 11               Ahmed El Mohamady              Aston Villa             0
# 12          Ainsley Maitland-Niles               Arsenal FC             0
# 13                      Alex Iwobi               Everton FC             0
# 14                   Alex McCarthy           Southampton FC             0
# 15             Alex Nicolao Telles        Manchester United             0
# 16             Alexandre Lacazette               Arsenal FC             3
# 17             Alexis Mac Allister   Brighton & Hove Albion             1
# 18             Alireza Jahanbakhsh   Brighton & Hove Albion             0
# 19           Alisson Ramses Becker             Liverpool FC             0
# 20          Allan Marques Loureiro               Everton FC             0
# 21             Allan Saint-Maximin         Newcastle United             1
# 22                 Alphonse Areola                Fulham FC             0
# 23      André-Frank Zambo Anguissa                Fulham FC             0
# 24      André Filipe Tavares Gomes               Everton FC             0
# 25             Andreas Christensen               Chelsea FC             0
# 26                Andrew Robertson             Liverpool FC             1
# 27               Andriy Yarmolenko          West Ham United             0
# 28                 Andros Townsend           Crystal Palace             1
# 29                    Andy Carroll         Newcastle United             0
#
#     assists  minutes  clean_sheets  position_index  total_points  \
# 0         1      441             1               5            23
# 1         4     1080             4               2            53
# 2         0     1080             0               1            28
# 3         0      900             3               2            35
# 4         1      998             2               3            31
# 5         0      249             0               4             4
# 6         1      523             2               4            20
# 7         0      990             2               2            23
# 8         0      700             1               4            17
# 9         2      738             1               4            35
# 10        0      180             0               1             2
# 11        0       35             0               2             3
# 12        0      204             1               3            11
# 13        2      513             2               4            24
# 14        0     1080             5               1            50
# 15        1      263             1               2            12
# 16        0      643             2               5            30
# 17        0       61             0               4            12
# 18        1      118             0               4             9
# 19        0      810             2               1            35
# 20        0      988             2               3            20
# 21        1      582             3               4            28
# 22        0      990             1               1            30
# 23        2      923             1               3            30
# 24        0      453             2               3            14
# 25        0      315             0               2             2
# 26        3     1080             3               2            53
# 27        0       97             0               4             4
# 28        2      838             2               4            38
# 29        1      178             1               5            11
#
#     Predicted Points  Actual FPPG  Predicted FPPG
# 0          23.043504     4.693878        4.702756
# 1          54.666899     4.416667        4.555575
# 2          20.716958     2.333333        1.726413
# 3          35.084366     3.500000        3.508437
# 4          36.273370     2.795591        3.271146
# 5           8.692313     1.445783        3.141800
# 6          17.649000     3.441683        3.037113
# 7          25.749083     2.090909        2.340826
# 8          20.282100     2.185714        2.607699
# 9          46.143694     4.268293        5.627280
# 10          5.540872     1.000000        2.770436
# 11          1.643142     7.714286        4.225222
# 12          4.366811     4.852941        1.926534
# 13         22.030675     4.210526        3.865031
# 14         53.069307     4.166667        4.422442
# 15         13.351191     4.106464        4.568849
# 16         34.773793     4.199067        4.867249
# 17         10.880331    17.704918       16.052947
# 18          9.340946     6.864407        7.124450
# 19         30.684533     3.888889        3.409393
# 20         23.842135     1.821862        2.171854
# 21         25.567296     4.329897        3.953706
# 22         27.288407     2.727273        2.480764
# 23         32.506812     2.925244        3.169678
# 24         10.425496     2.781457        2.071290
# 25          6.848807     0.571429        1.956802
# 26         47.492116     4.416667        3.957676
# 27          3.586508     3.711340        3.327688
# 28         39.574114     4.081146        4.250203
# 29         11.886926     5.561798        6.010244

# %%
df_21_x[df_21_x['player_name'] == "Harry Kane"]
# Out:
#     player_name          club_name  goals_scored  assists  minutes  \
# 155  Harry Kane  Tottenham Hotspur             9       10     1073
#
#      clean_sheets  position_index  total_points  Predicted Points  \
# 155             5               5           107        109.547817
#
#      Actual FPPG  Predicted FPPG
# 155     8.974837         9.18854
